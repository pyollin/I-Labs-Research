# %% [markdown]
# # Investigating Reuduction Factor as a function or External Expansion Order
# ## Paul Yollin

# %%
import Funfile as Fun
import numpy as np
import matplotlib.pyplot as plt

params = {
    'f_ext': 'Hz_10v_erm_raw.fif',
    '5': {'start': 80, 'stop': 120},
    '20': {'start': 0, 'stop': 40},
    '70': {'start': 70, 'stop': 110},
    '105': {'start': 65, 'stop': 105}
}

drops = {
    '2': {},
    '4': {},
    '6': {},
    '8': {},
    '10': {},
    '12': {}
}

xs = np.arange(1,8)

# %% [markdown]
# ### 5Hz reduction factor with varying expansion orders

# %%
for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        dat = Fun.RecClass('5' + str(params['f_ext']),
                           params['5']['start'],
                           params['5']['stop'],
                           int(i), int(e))
        drops[i][e] = Fun.find_drop(dat.data)
del i,e
;
# Out:
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# ...

# %%
mdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

gdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

fig, ax = plt.subplots(1, 2, figsize=(13,7))

for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        mdrop[i][e-1] = drops[i][e]['mcdat']
        gdrop[i][e-1] = drops[i][e]['gcdat']

    ax[0].plot(xs, mdrop[i], label=i+' (Int Order)')
    ax[1].plot(xs, gdrop[i], label=i+' (Int Order)')

del i, e
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')
ax[0].grid()
ax[1].grid()
ax[0].set(title='Magnetometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')

ax[1].set(title='Gradiometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')
# Out:
# [Text(0, 0.5, 'Reduction Factor'),
#  Text(0.5, 0, 'Expansion order (external)'),
#  Text(0.5, 1.0, 'Gradiometer Drops over expansion order')]

# %% [markdown]
# ### 20Hz reduction factor with varying expansion orders

# %%
for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        dat = Fun.RecClass('5' + str(params['f_ext']),
                           params['20']['start'],
                           params['20']['stop'],
                           int(i), int(e))
        drops[i][e] = Fun.find_drop(dat.data)
del i,e
# Out:
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# ...

# %%
mdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

gdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

fig, ax = plt.subplots(1, 2, figsize=(13,7))

for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        mdrop[i][e-1] = drops[i][e]['mcdat']
        gdrop[i][e-1] = drops[i][e]['gcdat']

    ax[0].plot(xs, mdrop[i], label=i+' (Int Order)')
    ax[1].plot(xs, gdrop[i], label=i+' (Int Order)')

del i, e
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')
ax[0].grid()
ax[1].grid()
ax[0].set(title='Magnetometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')

ax[1].set(title='Gradiometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')
# Out:
# [Text(0, 0.5, 'Reduction Factor'),
#  Text(0.5, 0, 'Expansion order (external)'),
#  Text(0.5, 1.0, 'Gradiometer Drops over expansion order')]

# %% [markdown]
# ### 70Hz reduction factor with varying expansion orders

# %%
for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        dat = Fun.RecClass('5' + str(params['f_ext']),
                           params['70']['start'],
                           params['70']['stop'],
                           int(i), int(e))
        drops[i][e] = Fun.find_drop(dat.data)
del i,e
# Out:
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# ...

# %%
mdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

gdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

fig, ax = plt.subplots(1, 2, figsize=(13,7))

for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        mdrop[i][e-1] = drops[i][e]['mcdat']
        gdrop[i][e-1] = drops[i][e]['gcdat']

    ax[0].plot(xs, mdrop[i], label=i+' (Int Order)')
    ax[1].plot(xs, gdrop[i], label=i+' (Int Order)')

del i, e
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')
ax[0].grid()
ax[1].grid()
ax[0].set(title='Magnetometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')

ax[1].set(title='Gradiometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')
# Out:
# [Text(0, 0.5, 'Reduction Factor'),
#  Text(0.5, 0, 'Expansion order (external)'),
#  Text(0.5, 1.0, 'Gradiometer Drops over expansion order')]

# %% [markdown]
# ### 105Hz reduction factor with varying expansion orders

# %%
for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        dat = Fun.RecClass('5' + str(params['f_ext']),
                           params['105']['start'],
                           params['105']['stop'],
                           int(i), int(e))
        drops[i][e] = Fun.find_drop(dat.data)
del i,e
# Out:
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# 102 of 102 T1/T2 magnetometer types replaced with T3.
# ...

# %%
mdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

gdrop = {
    '2': np.zeros(7),
    '4': np.zeros(7),
    '6': np.zeros(7),
    '8': np.zeros(7),
    '10': np.zeros(7),
    '12': np.zeros(7)
}

fig, ax = plt.subplots(1, 2, figsize=(13,7))

for i in ['2', '4', '6', '8', '10', '12']:
    for e in xs:
        mdrop[i][e-1] = drops[i][e]['mcdat']
        gdrop[i][e-1] = drops[i][e]['gcdat']

    ax[0].plot(xs, mdrop[i], label=i+' (Int Order)')
    ax[1].plot(xs, gdrop[i], label=i+' (Int Order)')

del i, e
ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')
ax[0].grid()
ax[1].grid()
ax[0].set(title='Magnetometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')

ax[1].set(title='Gradiometer Drops over expansion order',
          xlabel='Expansion order (external)',
          ylabel='Reduction Factor')
# Out:
# [Text(0, 0.5, 'Reduction Factor'),
#  Text(0.5, 0, 'Expansion order (external)'),
#  Text(0.5, 1.0, 'Gradiometer Drops over expansion order')]
